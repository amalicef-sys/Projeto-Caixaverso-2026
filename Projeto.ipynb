# %%
import pandas as pd
import numpy as np

# %%
datatran = pd.read_csv('dados/datatran2025.csv', sep=';', decimal=',', encoding='latin-1', parse_dates=['data_inversa'])
datatran.head()
#datatran.tail()

# %%
datatran.info()

# %%
print(datatran.isna().sum())

# %%
datatran.describe().round(2)
